# %% [markdown]
# # Kenya Clinical Reasoning Challenge

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train_raw = pd.read_csv('train_raw.csv')

# %% [markdown]
# ##### Train

# %%
train.columns
# Out:
# Index(['Master_Index', 'County', 'Health level', 'Years of Experience',
#        'Prompt', 'Nursing Competency', 'Clinical Panel', 'Clinician', 'GPT4.0',
#        'LLAMA', 'GEMINI', 'DDX SNOMED'],
#       dtype='object')

# %%
# checking the volume of data we have for train
print(f"Shape of the training data: {train.shape}")
train.head()
# Out:
# Shape of the training data: (400, 12)
#   Master_Index       County                            Health level  \
# 0     ID_VBWWP  uasin gishu  sub county hospitals and nursing homes
# 1     ID_XMBBY  uasin gishu             national referral hospitals
# 2     ID_JZNZW       kiambu  sub county hospitals and nursing homes
# 3     ID_QOQTK  uasin gishu             national referral hospitals
# 4     ID_ZFJBM  uasin gishu             national referral hospitals
#
#    Years of Experience                                             Prompt  \
# 0                 18.0  i am a nurse with 18 years of experience in ge...
# 1                 17.0  i am a nurse with 17 years of experience in ge...
# 2                 12.0  i am a nurse with 12 years of experience in ge...
# 3                 12.0  i am a nurse with 12 years of experience in pr...
# 4                 16.0  i am a nurse with 16 years of experience in ge...
#
#           Nursing Competency     Clinical Panel  \
# 0  pediatric emergency burns            surgery
# 1               child health        paediatrics
# 2          general emergency  internal medicine
# 3              critical care  internal medicine
# 4               adult health  internal medicine
#
#                                            Clinician  \
# 0  summary a 4 year old with 5 superficial burns ...
# 1  summary 6 year old present with vomiting and a...
# 2  summary a 47 year old man presents with severe...
# 3  summary 72 year old female with inability to w...
# 4  a 22 year old female presents with headache di...
#
#                                               GPT4.0  \
# 0  given your vast experience as a nurse in uasin...
# 1  clinical summary • a 6 year old girl with know...
# 2  in this case you re dealing with a 47 year old...
# 3  given er s clinical presentation and vitals th...
# 4  the 22 year old female patient is presenting w...
#
#                                                LLAMA  \
# 0  1 immediate treatment protocol for second degr...
# 1  based on the symptoms and signs you ve describ...
# 2  firstly i must commend you on your thorough hi...
# 3  to me with this query based on the information...
# 4  thank you for presenting this case based on th...
#
#                                               GEMINI  \
# 0  here s a response addressing the questions reg...
# 1  based on the presentation the 6 year old girl ...
# 2  this 47 year old male presenting with severe r...
# 3  this 92 year old female patient er presents wi...
# 4  this 22 year old female patient presents with ...
#
#                                           DDX SNOMED
# 0  288514009 burn involving 5 percent of body sur...
# 1  420270002 ketoacidosis due to type 1 diabetes ...
# 2  13200003 peptic ulcer disorder 25458004 acute ...
# 3  14760008 constipation finding 419284004 altere...
# 4  95874006 carbon monoxide poisoning from fire d...

# %%
# missing values
print(f"Missing values:\n {train.isnull().sum()}\n")

# percentage of missing values
print(f"Missing values percentage:\n {train.isnull().mean() * 100}\n")

# Show rows with any missing values
missing_rows = train[train.isnull().any(axis=1)]
print(f"Missing rows:\n {missing_rows}")
# Out:
# Missing values:
#  Master_Index             0
# County                   0
# Health level             0
# Years of Experience    100
# Prompt                   0
# Nursing Competency       0
# Clinical Panel           0
# Clinician                0
# GPT4.0                   0
# LLAMA                    0
# GEMINI                   0
# DDX SNOMED               1
# dtype: int64
#
# Missing values percentage:
#  Master_Index            0.00
# County                  0.00
# Health level            0.00
# Years of Experience    25.00
# Prompt                  0.00
# Nursing Competency      0.00
# Clinical Panel          0.00
# Clinician               0.00
# GPT4.0                  0.00
# LLAMA                   0.00
# GEMINI                  0.00
# DDX SNOMED              0.25
# dtype: float64
#
# Missing rows:
#      Master_Index       County                            Health level  \
# 7       ID_SUOCB  uasin gishu             national referral hospitals
# 10      ID_LPHGS     kakamega                          health centres
# 16      ID_DBLHH  uasin gishu                          health centres
# 18      ID_GMPJA     kakamega                          health centres
# 19      ID_GULKY       kiambu        dispensaries and private clinics
# ..           ...          ...                                     ...
# 384     ID_VNCRE  uasin gishu             national referral hospitals
# 386     ID_YMSLH  uasin gishu             national referral hospitals
# 390     ID_QMUCF     kakamega        dispensaries and private clinics
# 396     ID_JNZVU  uasin gishu             national referral hospitals
# 399     ID_FITJT     kakamega  sub county hospitals and nursing homes
#
#      Years of Experience                                             Prompt  \
# 7                    NaN  i am a nurse working in a national referral ho...
# 10                   NaN  i am a nurse working in a health centres in ka...
# 16                   NaN  i am a nurse working in a health centres in ua...
# 18                   NaN  i am a nurse working in a health centres in ka...
# 19                   NaN  i am a nurse working in a dispensaries and pri...
# ..                   ...                                                ...
# 384                  NaN  i am a nurse working in a national referral ho...
# 386                  NaN  i am a nurse working in a national referral ho...
# 390                  NaN  i am a nurse working in a dispensaries and pri...
# 396                  NaN  i am a nurse working in a national referral ho...
# 399                  NaN  i am a nurse working in a sub county hospitals...
#
#                  Nursing Competency              Clinical Panel  \
# 7                      child health                     surgery
# 10                general emergency                     surgery
# 16   sexual and reproductive health  obstetrics and gynaecology
# 18               emergency care gbv           internal medicine
# 19        maternal and child health                 paediatrics
# ..                              ...                         ...
# 384                    child health                 paediatrics
# 386       maternal and child health  obstetrics and gynaecology
# 390  sexual and reproductive health  obstetrics and gynaecology
# 396  sexual and reproductive health           internal medicine
# 399               general emergency           internal medicine
#
#                                              Clinician  \
# 7    a 10 year old presenting with lump fever and l...
# 10   summary 19yr old boy involved in rta on examin...
# 16   summary a 26 year old female with complaints o...
# 18   summary a 32 year old reports being in abusive...
# 19   summary 1 month old baby wet umbilical cord dx...
# ..                                                 ...
# 384  summary 1 year old boy with vomiting and fever...
# 386  summary a 28 year old woman admitted at 38 wee...
# 390  summary 26 year old came to the clinic with pr...
# 396  summary a 68 year old male presents with fever...
# 399  summary a 40 year old man is brought to outpat...
#
#                                                 GPT4.0  \
# 7    the presentation of a 10 year old boy with a l...
# 10   given the patient s history and presentation s...
# 16   based on the symptoms and history provided the...
# 18   yes it is absolutely appropriate for the healt...
# 19   the scenario involves a 1 month old baby with ...
# ..                                                 ...
# 384  what could be causing recurrent fever and vomi...
# 386  thank you for providing the detailed case this...
# 390  case analysis a 26 year old client presents wi...
# 396  for a 38 year old para 3 woman presenting with...
# 399  in the case of a 40 year old male patient with...
#
#                                                  LLAMA  \
# 7    based on the symptoms and x ray findings i ll ...
# 10   given the patient s history of a road accident...
# 16   thank you for presenting this case based on th...
# 18   this is a very sensitive and critical situatio...
# 19   this is a concerning presentation and you mana...
# ..                                                 ...
# 384  given the child s history of recurrent fever a...
# 386  1 is it recommended to do ict test to all the ...
# 390  given the client s symptoms and history there ...
# 396  based on the symptoms you ve described it s es...
# 399  given the patient s history of asthma and curr...
#
#                                                 GEMINI  \
# 7    given the presentation of a 10 year old boy wi...
# 10   you absolutely should not stitch the wound tre...
# 16   this 26 year old female is presenting with cla...
# 18   yes it is absolutely proper and ethically requ...
# 19   this case presents a concerning situation a on...
# ..                                                 ...
# 384  this 1 year old boy presents with recurrent fe...
# 386  let s address your questions regarding this pr...
# 390  this 26 year old patient presenting with three...
# 396  this 38 year old woman presents with concernin...
# 399  in a sub county hospital in kakamega county ke...
#
#                                             DDX SNOMED
# 7    307576001 osteosarcoma of bone disorder 601680...
# 10   66551002 psychogenic headache finding 10844110...
# 16   419760006 bacterial vaginosis disorder 2259560...
# 18                                                 NaN
# 19   239095007 omphalitis disorder 91302008 sepsis ...
# ..                                                 ...
# 384  61462000 malaria disorder 91302008 sepsis diso...
# 386  199582007 rhesus isoimmunization delivered dis...
# 390  82536003 abnormal hormonal requirement finding...
# 396  95883001 bacterial meningitis disorder 5817000...
# 399  281239006 exacerbation of asthma disorder 2336...
#
# [100 rows x 12 columns]

# %%
# Count total duplicate rows
print(f"Duplicated values: {train.duplicated().sum()}\n")

# View duplicate rows
duplicates = train[train.duplicated()]
print(f"Duplicates:\n {duplicates}\n")

# Optionally, drop duplicates
# df = df.drop_duplicates()
# Out:
# Duplicated values: 0
#
# Duplicates:
#  Empty DataFrame
# Columns: [Master_Index, County, Health level, Years of Experience, Prompt, Nursing Competency, Clinical Panel, Clinician, GPT4.0, LLAMA, GEMINI, DDX SNOMED]
# Index: []

# %% [markdown]
# ##### Train_Raw

# %%
# check columns
train_raw.columns
# Out:
# Index(['Master_Index', 'County', 'Health level', 'Years of Experience',
#        'Prompt', 'Nursing Competency', 'Clinical Panel', 'Clinician', 'GPT4.0',
#        'LLAMA', 'GEMINI', 'DDX SNOMED'],
#       dtype='object')

# %%
# checking the volume of data we have for train_raw
print(f"Shape of the training data: {train_raw.shape}")
train_raw.head()
# Out:
# Shape of the training data: (400, 12)
#   Master_Index       County                            Health level  \
# 0     ID_VBWWP  Uasin Gishu  Sub-county Hospitals and Nursing Homes
# 1     ID_XMBBY  Uasin Gishu             National Referral Hospitals
# 2     ID_JZNZW       Kiambu  Sub-county Hospitals and Nursing Homes
# 3     ID_QOQTK  Uasin Gishu             National Referral Hospitals
# 4     ID_ZFJBM  Uasin Gishu             National Referral Hospitals
#
#    Years of Experience                                             Prompt  \
# 0                 18.0  I am a nurse with 18 years of experience in Ge...
# 1                 17.0  I am a nurse with 17 years of experience in Ge...
# 2                 12.0  I am a nurse with 12 years of experience in Ge...
# 3                 12.0  I am a nurse with 12 years of experience in Pr...
# 4                 16.0  I am a nurse with 16 years of experience in Ge...
#
#           Nursing Competency     Clinical Panel  \
# 0  Pediatric Emergency Burns            SURGERY
# 1               Child Health        PAEDIATRICS
# 2          General Emergency  INTERNAL MEDICINE
# 3              Critical Care  INTERNAL MEDICINE
# 4               Adult Health  INTERNAL MEDICINE
#
#                                            Clinician  \
# 0  Summary:\nA 4 year old with 5% superficial bur...
# 1  Summary\n6-year-old present with vomiting and ...
# 2  Summary\nA 47-year-old man presents with sever...
# 3  SUMMARY\n\n72-year-old female with inability t...
# 4  A 22 year old female presents with headache, d...
#
#                                               GPT4.0  \
# 0  Given your vast experience as a nurse in Uasin...
# 1  Clinical Summary: •        A 6-year-old girl w...
# 2  In this case, you're dealing with a 47-year-ol...
# 3  Given ER's clinical presentation and vitals, t...
# 4  The 22-year-old female patient is presenting w...
#
#                                                LLAMA  \
# 0  1. Immediate treatment protocol for second-deg...
# 1  Based on the symptoms and signs you've describ...
# 2  Firstly, I must commend you on your thorough h...
# 3  to me with this query. Based on the informatio...
# 4  Thank you for presenting this case. Based on t...
#
#                                               GEMINI  \
# 0  Here's a response addressing the questions reg...
# 1  Based on the presentation, the 6-year-old girl...
# 2  This 47-year-old male presenting with severe, ...
# 3  This 92-year-old female patient (ER) presents ...
# 4  This 22-year-old female patient presents with ...
#
#                                           DDX SNOMED
# 0  288514009 | Burn involving 5 percent of body s...
# 1  420270002 | Ketoacidosis due to type 1 diabete...
# 2  13200003 | Peptic ulcer (disorder)\n25458004 |...
# 3  14760008 | Constipation (finding)\n419284004 |...
# 4  95874006 | Carbon monoxide poisoning from fire...

# %%
# missing values
print(f"Missing values:\n {train_raw.isnull().sum()}\n")

# percentage of missing values
print(f"Missing values percentage:\n {train_raw.isnull().mean() * 100}\n")

# Show rows with any missing values
missing_rows = train_raw[train_raw.isnull().any(axis=1)]
print(f"Missing rows:\n {missing_rows}")
# Out:
# Missing values:
#  Master_Index             0
# County                   0
# Health level             0
# Years of Experience    100
# Prompt                   0
# Nursing Competency       0
# Clinical Panel           0
# Clinician                0
# GPT4.0                   0
# LLAMA                    0
# GEMINI                   0
# DDX SNOMED               1
# dtype: int64
#
# Missing values percentage:
#  Master_Index            0.00
# County                  0.00
# Health level            0.00
# Years of Experience    25.00
# Prompt                  0.00
# Nursing Competency      0.00
# Clinical Panel          0.00
# Clinician               0.00
# GPT4.0                  0.00
# LLAMA                   0.00
# GEMINI                  0.00
# DDX SNOMED              0.25
# dtype: float64
#
# Missing rows:
#      Master_Index       County                            Health level  \
# 7       ID_SUOCB  Uasin Gishu             National Referral Hospitals
# 10      ID_LPHGS     Kakamega                          Health centres
# 16      ID_DBLHH  Uasin Gishu                          Health centres
# 18      ID_GMPJA     Kakamega                          Health centres
# 19      ID_GULKY       Kiambu        Dispensaries and Private Clinics
# ..           ...          ...                                     ...
# 384     ID_VNCRE  Uasin Gishu             National Referral Hospitals
# 386     ID_YMSLH  Uasin Gishu             National Referral Hospitals
# 390     ID_QMUCF     Kakamega        Dispensaries and Private Clinics
# 396     ID_JNZVU  Uasin Gishu             National Referral Hospitals
# 399     ID_FITJT     Kakamega  Sub-county Hospitals and Nursing Homes
#
#      Years of Experience                                             Prompt  \
# 7                    NaN  I am a nurse working in a National Referral Ho...
# 10                   NaN  I am a nurse working in a Health centres in Ka...
# 16                   NaN  I am a nurse working in a Health centres in Ua...
# 18                   NaN  I am a nurse working in a Health centres in Ka...
# 19                   NaN  I am a nurse working in a Dispensaries and Pri...
# ..                   ...                                                ...
# 384                  NaN  I am a nurse working in a National Referral Ho...
# 386                  NaN  I am a nurse working in a National Referral Ho...
# 390                  NaN  I am a nurse working in a Dispensaries and Pri...
# 396                  NaN  I am a nurse working in a National Referral Ho...
# 399                  NaN  I am a nurse working in a Sub-county Hospitals...
#
#                  Nursing Competency              Clinical Panel  \
# 7                      Child Health                     SURGERY
# 10                General Emergency                     SURGERY
# 16   Sexual And Reproductive Health  OBSTETRICS AND GYNAECOLOGY
# 18             Emergency Care - GBV           INTERNAL MEDICINE
# 19        Maternal and Child Health                 PAEDIATRICS
# ..                              ...                         ...
# 384                    Child Health                 PAEDIATRICS
# 386       Maternal and Child Health  OBSTETRICS AND GYNAECOLOGY
# 390  Sexual And Reproductive Health  OBSTETRICS AND GYNAECOLOGY
# 396  Sexual And Reproductive Health           INTERNAL MEDICINE
# 399               General Emergency           INTERNAL MEDICINE
#
#                                              Clinician  \
# 7    A 10 year old presenting with lump fever and l...
# 10   SUMMARY\n19yr old boy involved in RTA On exami...
# 16   SUMMARY\nA 26 year old female with complaints ...
# 18   SUMMARY\nA 32 year old reports being in abusiv...
# 19   SUMMARY\n1 month old baby wet-umbilical cord\n...
# ..                                                 ...
# 384  SUMMARY\n1 year old boy with vomiting and feve...
# 386  SUMMARY\nA 28-year-old woman admitted at 38 we...
# 390  Summary\n26 year old came to the clinic with p...
# 396  Summary:\nA 68-year-old male presents with fev...
# 399  Summary\nA 40 year old man is brought to outpa...
#
#                                                 GPT4.0  \
# 7    The presentation of a 10-year-old boy with a l...
# 10   Given the patient's history and presentation, ...
# 16   Based on the symptoms and history provided, th...
# 18   Yes, it is absolutely appropriate for the heal...
# 19   The scenario involves a 1-month-old baby with ...
# ..                                                 ...
# 384  What could be causing recurrent fever and vomi...
# 386  Thank you for providing the detailed case. Thi...
# 390  Case Analysis: A 26-year-old client presents w...
# 396  For a 38-year-old para 3 woman presenting with...
# 399  In the case of a 40-year-old male patient with...
#
#                                                  LLAMA  \
# 7    Based on the symptoms and X-ray findings, I'll...
# 10   Given the patient's history of a road accident...
# 16   Thank you for presenting this case. Based on t...
# 18   This is a very sensitive and critical situatio...
# 19   This is a concerning presentation, and you man...
# ..                                                 ...
# 384  Given the child's history of recurrent fever a...
# 386  1. Is it recommended to do ICT test to all the...
# 390  Given the client's symptoms and history, there...
# 396  Based on the symptoms you've described, it's e...
# 399  Given the patient's history of asthma and curr...
#
#                                                 GEMINI  \
# 7    Given the presentation of a 10-year-old boy wi...
# 10   You absolutely should not stitch the wound, tr...
# 16   This 26-year-old female is presenting with cla...
# 18   Yes, it is absolutely proper and ethically req...
# 19   This case presents a concerning situation: a o...
# ..                                                 ...
# 384  This 1-year-old boy presents with recurrent fe...
# 386  Let's address your questions regarding this pr...
# 390  This 26-year-old patient presenting with three...
# 396  This 38-year-old woman presents with concernin...
# 399  In a Sub-county hospital in Kakamega County, K...
#
#                                             DDX SNOMED
# 7    307576001 | Osteosarcoma of bone (disorder)\n6...
# 10   66551002 | Psychogenic headache (finding)\n108...
# 16   419760006 | Bacterial vaginosis (disorder)\n22...
# 18                                                 NaN
# 19   239095007 | Omphalitis (disorder)\n91302008 | ...
# ..                                                 ...
# 384  61462000 | Malaria (disorder)\n91302008 | Seps...
# 386  199582007 | Rhesus isoimmunization - delivered...
# 390  82536003 | Abnormal hormonal requirement (find...
# 396  95883001 | Bacterial meningitis (disorder)\n58...
# 399  281239006 | Exacerbation of asthma (disorder)\...
#
# [100 rows x 12 columns]

# %%
# Count total duplicate rows
print(f"Duplicated values:\n {train_raw.duplicated().sum()}\n")

# View duplicate rows
duplicates = train_raw[train_raw.duplicated()]
print(f"Duplicates:\n {duplicates}\n")

# Optionally, drop duplicates
# df = df.drop_duplicates()
# Out:
# Duplicated values:
#  0
#
# Duplicates:
#  Empty DataFrame
# Columns: [Master_Index, County, Health level, Years of Experience, Prompt, Nursing Competency, Clinical Panel, Clinician, GPT4.0, LLAMA, GEMINI, DDX SNOMED]
# Index: []

# %% [markdown]
# ##### Test

# %%
# checking the columns:
test.columns
# Out:
# Index(['Master_Index', 'County', 'Health level', 'Years of Experience',
#        'Prompt', 'Nursing Competency', 'Clinical Panel'],
#       dtype='object')

# %%
# checking the volume of data we have for test
print(f"Shape of the training data: {test.shape}")
test.head()
# Out:
# Shape of the training data: (100, 7)
#   Master_Index       County                            Health level  \
# 0     ID_CUAOY  uasin gishu  sub county hospitals and nursing homes
# 1     ID_OGSAY       kiambu  sub county hospitals and nursing homes
# 2     ID_TYHSA  uasin gishu             national referral hospitals
# 3     ID_CZXLD     kakamega        dispensaries and private clinics
# 4     ID_ZJQUQ     kakamega                          health centres
#
#    Years of Experience                                             Prompt  \
# 0                  2.0  i am a nurse with 2 years of experience in gen...
# 1                 22.0  i am a nurse with 22 years of experience in ge...
# 2                  NaN  i am a nurse working in a national referral ho...
# 3                  NaN  i am a nurse working in a dispensaries and pri...
# 4                  NaN  i am a nurse working in a health centres in ka...
#
#   Nursing Competency     Clinical Panel
# 0       adult health        surgery ent
# 1       child health            surgery
# 2  general emergency  internal medicine
# 3       child health        paediatrics
# 4       child health        paediatrics

# %%
# missing values
print(f"Missing values:\n {test.isnull().sum()}\n")

# percentage of missing values
print(f"Missing values percentage:\n {test.isnull().mean() * 100}\n")

# Show rows with any missing values
missing_rows = test[test.isnull().any(axis=1)]
print(f"Missing rows:\n {missing_rows}")
# Out:
# Missing values:
#  Master_Index            0
# County                  0
# Health level            0
# Years of Experience    25
# Prompt                  0
# Nursing Competency      0
# Clinical Panel          0
# dtype: int64
#
# Missing values percentage:
#  Master_Index            0.0
# County                  0.0
# Health level            0.0
# Years of Experience    25.0
# Prompt                  0.0
# Nursing Competency      0.0
# Clinical Panel          0.0
# dtype: float64
#
# Missing rows:
#     Master_Index       County                            Health level  \
# 2      ID_TYHSA  uasin gishu             national referral hospitals
# 3      ID_CZXLD     kakamega        dispensaries and private clinics
# 4      ID_ZJQUQ     kakamega                          health centres
# 7      ID_GDFDN     kakamega                          health centres
# 8      ID_UFAFI       kiambu  sub county hospitals and nursing homes
# 13     ID_KQFSM     kakamega        dispensaries and private clinics
# 20     ID_VJVBS  uasin gishu             national referral hospitals
# 21     ID_OZCVT  uasin gishu             national referral hospitals
# 26     ID_GWZRC  uasin gishu             national referral hospitals
# 28     ID_QDMBJ     kakamega                          health centres
# 30     ID_APFPK  uasin gishu                          health centres
# 41     ID_DGSSB     kakamega  sub county hospitals and nursing homes
# 50     ID_SIPNK       kiambu                          health centres
# 55     ID_DCOHP       kiambu  sub county hospitals and nursing homes
# 56     ID_RWISH     kakamega  sub county hospitals and nursing homes
# 59     ID_XQHOA       kiambu  sub county hospitals and nursing homes
# 63     ID_QSQZO  uasin gishu  sub county hospitals and nursing homes
# 64     ID_HLPRM       kiambu  sub county hospitals and nursing homes
# 65     ID_WOBZV       kiambu                          health centres
# 67     ID_CEPRG       kiambu        dispensaries and private clinics
# 76     ID_NIVMV  uasin gishu             national referral hospitals
# 77     ID_WZHQK       kiambu  sub county hospitals and nursing homes
# 80     ID_PGEOO     kakamega  sub county hospitals and nursing homes
# 83     ID_WLSXB     kakamega  sub county hospitals and nursing homes
# 85     ID_XTMGG     kakamega        dispensaries and private clinics
#
#     Years of Experience                                             Prompt  \
# 2                   NaN  i am a nurse working in a national referral ho...
# 3                   NaN  i am a nurse working in a dispensaries and pri...
# 4                   NaN  i am a nurse working in a health centres in ka...
# 7                   NaN  i am a nurse working in a health centres in ka...
# 8                   NaN  i am a nurse working in a sub county hospitals...
# 13                  NaN  i am a nurse working in a dispensaries and pri...
# 20                  NaN  i am a nurse working in a national referral ho...
# 21                  NaN  i am a nurse working in a national referral ho...
# 26                  NaN  i am a nurse working in a national referral ho...
# 28                  NaN  i am a nurse working in a health centres in ka...
# 30                  NaN  i am a nurse working in a health centres in ua...
# 41                  NaN  i am a nurse working in a sub county hospitals...
# 50                  NaN  i am a nurse working in a health centres in ki...
# 55                  NaN  i am a nurse working in a sub county hospitals...
# 56                  NaN  i am a nurse working in a sub county hospitals...
# 59                  NaN  i am a nurse working in a sub county hospitals...
# 63                  NaN  i am a nurse working in a sub county hospitals...
# 64                  NaN  i am a nurse working in a sub county hospitals...
# 65                  NaN  i am a nurse working in a health centres in ki...
# 67                  NaN  i am a nurse working in a dispensaries and pri...
# 76                  NaN  i am a nurse working in a national referral ho...
# 77                  NaN  i am a nurse working in a sub county hospitals...
# 80                  NaN  i am a nurse working in a sub county hospitals...
# 83                  NaN  i am a nurse working in a sub county hospitals...
# 85                  NaN  i am a nurse working in a dispensaries and pri...
#
#                 Nursing Competency              Clinical Panel
# 2                general emergency           internal medicine
# 3                     child health                 paediatrics
# 4                     child health                 paediatrics
# 7        maternal and child health  obstetrics and gynaecology
# 8        maternal and child health           internal medicine
# 13       maternal and child health  obstetrics and gynaecology
# 20        emergency care pediatric                     surgery
# 21                    adult health           internal medicine
# 26                    adult health           internal medicine
# 28  sexual and reproductive health                 paediatrics
# 30                    child health                 paediatrics
# 41                    child health                     surgery
# 50                    adult health           internal medicine
# 55  sexual and reproductive health           internal medicine
# 56                   mental health           internal medicine
# 59       maternal and child health  obstetrics and gynaecology
# 63        emergency care pediatric                 paediatrics
# 64       maternal and child health  obstetrics and gynaecology
# 65       maternal and child health  obstetrics and gynaecology
# 67       maternal and child health  obstetrics and gynaecology
# 76       maternal and child health  obstetrics and gynaecology
# 77  sexual and reproductive health                     surgery
# 80                   surgical care   internal medicine surgery
# 83               general emergency           internal medicine
# 85                    child health                 paediatrics

# %%
# Count total duplicate rows
print(f"Duplicated values:\n {test.duplicated().sum()}\n")

# View duplicate rows
duplicates = test[test.duplicated()]
print(f"Duplicates:\n {duplicates}\n")

# Optionally, drop duplicates
# df = df.drop_duplicates()
# Out:
# Duplicated values:
#  0
#
# Duplicates:
#  Empty DataFrame
# Columns: [Master_Index, County, Health level, Years of Experience, Prompt, Nursing Competency, Clinical Panel]
# Index: []

# %% [markdown]
# ### Analysis

# %%
# 1. First analysis - Clinician Response Patterns
def analyze_responses(df):
    # Count structured terms
    summary_count = df['Clinician'].str.lower().str.contains('summary').sum()
    dx_count = df['Clinician'].str.lower().str.contains('dx').sum()
    plan_count = df['Clinician'].str.lower().str.contains('plan').sum()
    print(f"Responses with 'summary': {summary_count}/{len(df)} ({summary_count/len(df)*100:.1f}%)")
    print(f"Responses with 'dx': {dx_count}/{len(df)} ({dx_count/len(df)*100:.1f}%)")
    print(f"Responses with 'plan': {plan_count}/{len(df)} ({plan_count/len(df)*100:.1f}%)")

    # Word count
    df['clinician_word_count'] = df['Clinician'].str.split().str.len()
    print(f"Avg word count: {df['clinician_word_count'].mean():.1f}, Min: {df['clinician_word_count'].min()}, Max: {df['clinician_word_count'].max()}")

# %%
# train analysis response
analyze_responses(train)
# Out:
# Responses with 'summary': 325/400 (81.2%)
# Responses with 'dx': 85/400 (21.2%)
# Responses with 'plan': 28/400 (7.0%)
# Avg word count: 109.0, Min: 29, Max: 320

# %%
# train_raw analysis response
analyze_responses(train_raw)
# Out:
# Responses with 'summary': 325/400 (81.2%)
# Responses with 'dx': 85/400 (21.2%)
# Responses with 'plan': 28/400 (7.0%)
# Avg word count: 107.7, Min: 26, Max: 314

# %%
# 2. Second Analysis - Contextual Features
def explore_context(df):
    # Group by Health level
    health_summary = df.groupby('Health level')['clinician_word_count'].agg(['mean', 'count']).round(1)
    print("\nWord count by Health level:\n", health_summary)

    # Group by Nursing Competency
    competency_summary = df.groupby('Nursing Competency')['clinician_word_count'].agg(['mean', 'count']).round(1)
    print("\nWord count by Nursing Competency:\n", competency_summary)

    # Years of Experience vs. word count
    exp_summary = df.groupby('Years of Experience')['clinician_word_count'].agg(['mean', 'count']).round(1)
    print("\nWord count by Years of Experience:\n", exp_summary)

# %%
# train contextual features
explore_context(train)
# Out:
# Word count by Health level:
#                                           mean  count
# Health level
# community health centers                104.8      6
# county hospitals                         96.9      9
# dispensaries and private clinics        106.4     54
# health centers                          123.0      1
# health centres                          106.3     74
# national referral hospitals             110.7    125
# sub county hospitals and nursing homes  111.0    131
#
# Word count by Nursing Competency:
#                                   mean  count
# Nursing Competency
# adult health                    108.9    123
# child health                    104.3     56
# critical care                   139.0      2
# emergency care adult            102.0      2
# emergency care burns             98.0      1
# emergency care gbv               80.0      4
# emergency care mental health     60.0      1
# emergency care pediatric        109.3     23
# emergency care rape             162.7      3
# general emergency               112.7     66
# maternah and child health       152.0      1
# maternal and child health       120.5     53
# mayernal and child health       110.0      1
# mental health                    99.7     14
# neonatal care                    90.5     13
# obstetrics emergency             65.0      1
# pediatric emergency burns        47.0      1
# sexual and reproductive health  103.7     25
# surgical care                   102.3      9
# wound and ostomy care           119.0      1
#
# Word count by Years of Experience:
#                        mean  count
# Years of Experience
# 1.0                  100.7     21
# 2.0                  111.7     10
# 3.0                   92.6      5
# 5.0                  117.0      1
# 7.0                  101.3      3
# 8.0                   73.2      8
# 9.0                  130.3      7
# 10.0                 107.5     26
# 11.0                 104.0      1
# 12.0                 110.9     36
# 13.0                 113.0      1
# 14.0                 126.1     13
# 15.0                 126.6     26
# 16.0                 118.4     14
# 17.0                 102.2     16
# 18.0                  96.9      9
# 19.0                 117.8      5
# 20.0                 107.7     29
# 21.0                  80.5      2
# 22.0                 114.1     12
# 23.0                 144.4      5
# 24.0                  94.8     13
# 26.0                 102.2      4
# 27.0                 107.4      7
# 29.0                  96.7      6
# 30.0                 113.2     13
# 31.0                 105.8      4
# 38.0                 145.3      3

# %%
# train_raw contextual features
explore_context(train_raw)
# Out:
# Word count by Health level:
#                                           mean  count
# Health level
# Community Health Centers                102.5      6
# County Hospitals                         93.8      9
# Dispensaries and Private Clinics        104.4     54
# Health Centers                          122.0      1
# Health Centres                          121.0      5
# Health centres                          105.2     69
# National Referral Hospitals             109.2    125
# Sub-county Hospitals and Nursing Homes  109.4    131
#
# Word count by Nursing Competency:
#                                   mean  count
# Nursing Competency
# Adult Health                    107.0    123
# Child Health                    103.5     56
# Critical Care                   143.0      2
# Emergency Care - Adult           99.5      2
# Emergency Care - Burns           95.0      1
# Emergency Care - GBV             79.8      4
# Emergency Care - Mental Health   66.0      1
# Emergency Care - Pediatric      109.5     23
# Emergency Care - Rape           160.3      3
# General Emergency               110.3     66
# Maternal and Child Health       119.3     50
# Mental Health                   100.1     14
# Neonatal Care                    90.8     13
# Obstetrics Emergency             63.0      1
# Pediatric Emergency Burns        51.0      1
# Sexual And Reproductive Health  102.6     25
# Surgical Care                   103.8      9
# Wound and Ostomy Care           116.0      1
# maternah and child health       149.0      1
# maternal and child health       113.0      3
# mayernal and child health       105.0      1
#
# Word count by Years of Experience:
#                        mean  count
# Years of Experience
# 1.0                   99.6     21
# 2.0                  110.9     10
# 3.0                   93.0      5
# 5.0                  120.0      1
# 7.0                   97.7      3
# 8.0                   75.2      8
# 9.0                  130.1      7
# 10.0                 106.7     26
# 11.0                 104.0      1
# 12.0                 107.6     36
# 13.0                 112.0      1
# 14.0                 123.2     13
# 15.0                 125.0     26
# 16.0                 116.1     14
# 17.0                 101.6     16
# 18.0                  96.1      9
# 19.0                 115.4      5
# 20.0                 107.1     29
# 21.0                  78.5      2
# 22.0                 111.5     12
# 23.0                 135.8      5
# 24.0                  93.7     13
# 26.0                 101.0      4
# 27.0                 107.7      7
# 29.0                 102.7      6
# 30.0                 112.1     13
# 31.0                 102.8      4
# 38.0                 141.3      3

# %%
# 3. Preprocessing Function
def preprocess_clinician(text):
    # Convert to lowercase
    text = text.lower()
    # Keep only alphanumeric characters and spaces
    text = ''.join(c for c in text if c.isalnum() or c.isspace())
    # Replace multiple spaces/newlines with a single space
    text = ' '.join(text.split())
    return text

# %%
# Test preprocessing
sample_response = train['Clinician'][0]
print(f"Original:\n {sample_response}\n")
print(f"Preprocessed:\n{preprocess_clinician(sample_response)}")
# Out:
# Original:
#  summary a 4 year old with 5 superficial burns no other injuries immediate management paracetamol analgesics to to ensure child has minimal or no pain cleaning and frosting of wound with silver sulpha fizika topical prophylactic can be considered in this case good nutrition high protein diet
#
# Preprocessed:
# summary a 4 year old with 5 superficial burns no other injuries immediate management paracetamol analgesics to to ensure child has minimal or no pain cleaning and frosting of wound with silver sulpha fizika topical prophylactic can be considered in this case good nutrition high protein diet

# %%
# Test preprocessing
sample_response = train_raw['Clinician'][0]
print(f"Original:\n {sample_response}\n")
print(f"Preprocessed:\n{preprocess_clinician(sample_response)}")
# Out:
# Original:
#  Summary:
# A 4 year old with 5% superficial burns. No other injuries
#
# Immediate Management:
#
#  * Paracetamol analgesics to to ensure child has minimal
#  or no pain
#  * Cleaning and frosting of wound with silver sulpha-fizika
# * Topical prophylactic can be considered in this case
#  * Good nutrition - high protein diet
#
# Preprocessed:
# summary a 4 year old with 5 superficial burns no other injuries immediate management paracetamol analgesics to to ensure child has minimal or no pain cleaning and frosting of wound with silver sulphafizika topical prophylactic can be considered in this case good nutrition high protein diet

# %% [markdown]
# ### Handle missing value

# %%
def update_prompt(row):
    if pd.isna(row['Years of Experience']):
        # Insert "with unknown years of experience" after "I am a nurse"
        return row['Prompt'].replace("i am a nurse", "i am a nurse with unknown years of experience")
    return row['Prompt']

# %%
train['Prompt'] = train.apply(update_prompt, axis=1)
train_raw['Prompt'] = train_raw.apply(update_prompt, axis=1)
test['Prompt'] = test.apply(update_prompt, axis=1)

# %%
train.isnull().sum()
# Out:
# Master_Index              0
# County                    0
# Health level              0
# Years of Experience     100
# Prompt                    0
# Nursing Competency        0
# Clinical Panel            0
# Clinician                 0
# GPT4.0                    0
# LLAMA                     0
# GEMINI                    0
# DDX SNOMED                1
# clinician_word_count      0
# dtype: int64

# %%
# Check abbreviations in a few responses
for i in [1, 2, 3]:
    print(f"\nIndex {i}:\n", train_raw['Clinician'][i])
# Out:
# Index 1:
#  Summary
# 6-year-old present with vomiting and abdominal pains. Known diabetic on insulin but doesn’t take it as scheduled due to lack of funds.
# He is confused, Kussmaul breathing, fruity-scented breath, dry tongue & blurry vision.
#
# Vitals: Temp (N), pulse ↑ (120), BP ↓ (48), rapid laboured SpO₂ 90%.
#
# Diagnosis:
# Diabetic Ketoacidosis (DKA) in known DM type 1 patient due to insulin insufficiency and uncompliance.
#
# Differentials
# Sepsis in a knon diabetic patient
# Investigations:
#
# 1. Laboratory investigations:
#
# Urinalysis
# Blood gas analysis
# RBS
# HbA1c
# UECs
# CBC
#
#
#
# Management:
#
# 1. Insert IV large bore cannula.
#
# 2. Give normal saline bolus and maintenance fluids.
#
# 3. Check RBS regularly.
#
# 4. Give insulin 0.1 u/kg/hr (IV).
#
# 5. Monitor blood glucose levels.
#
# 6. Check UECs for hypokalemia – if present, add it to the IV fluid.
#
# 7. Treat underlying infection with antibiotics.
#
# 8. Do regular ketone, pH, and bicarbonate checks.
#
# Index 2:
#  Summary
# A 47-year-old man presents with severe persistent upper abdominal pain in the gastric area that started the previous night. He has a history of peptic ulcer disease. Vitals are normal. Patient is in distress.
# Problems:
# Severe pain
# History of peptic ulcer disease
# Distress and inability to sleep
# Management:
# Administer analgesia for the pain.
# Start IV fluids to correct possible volume depletion.
# Administer proton pump inhibitor for the gastrointestinal upset.
# Administer antibiotics if there are signs of peritonitis.
# Investigations:
# Complete blood counts to check for leukocytosis.
# Ultrasound.
# Do an erect abdominal X-ray (to look for air under the diaphragm).
# Provisional Diagnosis (Pdx):
# Acute exacerbation of peptic ulcer disease
#
# Index 3:
#  SUMMARY
#
# 72-year-old female with inability to walk, abdominal pain, generalized body malaise, and history of fecal impaction.
# On exam GCS is 14/15 and low oxygen saturation.
#
#
# Dx:
# constipation
# Altered mental status
#
# Management:
#
# Assess airway, breathing and circulation
# initiate oxygen therapy if necessary, intravenous fluids if hypotensive or with features of shock
# Establish intravenous line access.
# Do a random blood glucose test
# Perform a digital rectal examination. If fecal impaction, evacuate manually and also use enema
#
# Investigations:
#
# Laboratory:
#
# Full hemogram to identify cytopenias and signs of infection
# Renal function test to identify electrolyte abnormalities and uremia
# Liver function test to identify derangement and possibility of hepatic encephalopathy
# Random blood glucose to identify either hypoglycemia or hyperglycaemia and correct accordingly
# Blood gas analysis to identify electrolyte derangements, acid/base abnormalities and correct appropriately
#
#
# Radiology:
#
# Computed tomography of the head to rule in/out space occupying lesions, features of meningitis/meningoencephalitis
# Chest x-ray if patient has respiratory symptoms
#
# Abdominal-pelvic ultrasound to aid in identification of masses

# %% [markdown]
# ## Baseline Modelling

# %%
pip install transformers datasets torch pandas numpy
# Out:
# Requirement already satisfied: transformers in /home/ekow/anaconda3/lib/python3.12/site-packages (4.47.0)
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: torch in /home/ekow/anaconda3/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: pandas in /home/ekow/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy in /home/ekow/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: filelock in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (0.26.5)
# Requirement already satisfied: packaging>=20.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (2.32.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /home/ekow/anaconda3/lib/python3.12/site-packages (from transformers) (4.66.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-19.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /home/ekow/anaconda3/lib/python3.12/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (4.13.0)
# Requirement already satisfied: sympy in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (69.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ekow/anaconda3/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.77)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ekow/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ekow/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ekow/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ekow/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ekow/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ekow/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: six>=1.5 in /home/ekow/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ekow/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ekow/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ekow/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ekow/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ekow/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/ekow/anaconda3/lib/python3.12/site-packages (from sympy->torch) (1.3.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 215.3 kB/s eta 0:00:000:00:010:00:01:01
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 224.2 kB/s eta 0:00:001m205.9 kB/s eta 0:00:01
# Downloading pyarrow-19.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (42.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Downloading xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 3.1 MB/s eta 0:00:0031m2.8 MB/s eta 0:00:01
# Installing collected packages: xxhash, pyarrow, multiprocess, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# Successfully installed datasets-3.5.0 multiprocess-0.70.16 pyarrow-19.0.1 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Preparing the Data (using train_raw)

# %%
import pandas as pd
from datasets import Dataset

# Load data
train_raw = pd.read_csv('train_raw.csv')

# Preprocessing function (fixed from Phase 1)
def preprocess_clinician(text):
    text = text.lower()
    text = ''.join(c for c in text if c.isalnum() or c.isspace())
    text = ' '.join(text.split())
    return text

# Handle missing Years of Experience in Prompt
def update_prompt(row):
    if pd.isna(row['Years of Experience']):
        return row['Prompt'].replace("i am a nurse", "i am a nurse with unknown years of experience")
    return row['Prompt']

# Apply preprocessing
train_raw['Prompt'] = train_raw.apply(update_prompt, axis=1)
train_raw['Clinician'] = train_raw['Clinician'].apply(preprocess_clinician)

# Create a Hugging Face Dataset
data = {'input_text': train_raw['Prompt'], 'target_text': train_raw['Clinician']}
dataset = Dataset.from_dict(data)

# Split into train (80%) and validation (20%)
train_test_split = dataset.train_test_split(test_size=0.2, seed=42)
train_dataset = train_test_split['train']
val_dataset = train_test_split['test']

# Verify
print("Train sample:", train_dataset[0])
print("Validation sample:", val_dataset[0])
